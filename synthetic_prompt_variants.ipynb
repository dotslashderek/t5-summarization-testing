# %% [markdown]
# # Prompt Compression + Variant Generation
# This notebook batches prompts through `gpt-5-nano` to produce compressed prompts, token counts, and two stylistic variants for fine-tuning.

# %% [markdown]
# ## Workflow Overview
# 1. (Optional) install dependencies.
# 2. Configure your OpenAI API key.
# 3. Configure compression rules and helpers.
# 4. Run the processing cell to populate new columns in `training_data/very-short-prompt-dolly-data.csv`.
#
# If the run is interrupted, re-run the final cell: completed rows are skipped automatically.

# %%
# If running in a fresh environment, install the required packages first.
# !pip install --quiet --upgrade openai transformers

# %%
import os
from getpass import getpass

try:
    from openai import OpenAI
except ImportError as exc:
    raise ImportError('openai package not found. Install it via %pip install openai before continuing.') from exc

if not os.getenv('OPENAI_API_KEY'):
    os.environ['OPENAI_API_KEY'] = getpass('Enter your OpenAI API key: ').strip()

CLIENT = OpenAI(api_key=os.environ['OPENAI_API_KEY'])
print('API key configured. Ready to call gpt-5-nano.')
# Out:
# API key configured. Ready to call gpt-5-nano.

# %%
import os
import csv
import shutil
import tempfile
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from itertools import islice
from pathlib import Path
from typing import Iterable, Sequence

from openai import OpenAI
from pydantic import BaseModel
from transformers import AutoTokenizer

MODEL_NAME = 'gpt-5-nano'
TOKENIZER_PATH = Path('/Users/dotslashderek/workspace/Gravitee/small-prompt-compression')
FALLBACK_TOKENIZER_NAME = 'dotslashderek/short-prompt-compressor'
CSV_PATH = Path('training_data/very-short-prompt-dolly-data.csv')
FIELDNAMES = [
    'original',
    'original_token_count',
    'compressed_prompt',
    'compressed_token_count',
    'uncompressed_alt_one',
    'uncompressed_alt_two',
]
FLUSH_EVERY = 5
MAX_RETRIES = 4
RETRY_BACKOFF_SECONDS = 2
MAX_OUTPUT_TOKENS = 5000
REASONING_EFFORT = 'low'
VERBOSITY = 'low'
BATCH_SIZE = 6
MAX_WORKERS = 6
LIMIT = 100
PROCESS_ONLY_PENDING = True

SYSTEM_PROMPT = """You are PromptCompressor, an expert at rewriting prompts for downstream LLMs while preserving every constraint.

Workflow:
1. Read the original prompt carefully.
2. Produce two stylistic variants of the original. They must keep all facts and constraints but remain slightly more conversational.
3. Generate the most compressed prompt possible, double-checking against the original and both variants so nothing is lost.

Compression rules:
- Strip trailing punctuation (question marks, exclamation points, ellipses, periods) unless removing it alters the meaning.
- Drop optional articles, helper verbs, fillers, or polite wording when they are not required for meaning.
- Preserve entities, dates, numbers, units, modality, polarity, and ordering exactly.
- Prefer minimal punctuation overall; use simple separators such as semicolons only when grouping is ambiguous.
- If the original prompt is already minimal, return it unchanged.

Variant rules:
- Each variant must be semantically identical to the original.
- Include at least one harmless fluff token (e.g., conversational filler, doubled punctuation) in each variant.
- Keep variants roughly the same length as the original prompt.

Output format:
Return a JSON object with keys compressed_prompt, uncompressed_alt_one, uncompressed_alt_two. Do not add commentary or Markdown fences.
"""

if TOKENIZER_PATH.exists():
    TOKENIZER = AutoTokenizer.from_pretrained(str(TOKENIZER_PATH), use_fast=True)
else:
    TOKENIZER = AutoTokenizer.from_pretrained(FALLBACK_TOKENIZER_NAME, use_fast=True)

_CLIENT: OpenAI | None = None


class PromptVariants(BaseModel):
    compressed_prompt: str
    uncompressed_alt_one: str
    uncompressed_alt_two: str


def get_client() -> OpenAI:
    global _CLIENT
    if _CLIENT is None:
        api_key = os.getenv('OPENAI_API_KEY')
        if not api_key:
            raise RuntimeError('OPENAI_API_KEY environment variable is not set.')
        _CLIENT = OpenAI(api_key=api_key)
    return _CLIENT


def ensure_csv_schema(csv_path: Path, fieldnames: Sequence[str]):
    if not csv_path.exists():
        raise FileNotFoundError(f"{csv_path} not found.")
    with csv_path.open('r', encoding='utf-8', newline='') as handle:
        reader = csv.DictReader(handle)
        rows = list(reader)
        existing_fieldnames = reader.fieldnames or []
    field_set = set(fieldnames)
    normalized_rows = []
    needs_rewrite = existing_fieldnames != list(fieldnames)
    for row in rows:
        normalized = {field: row.get(field, '') for field in fieldnames}
        if set(row.keys()) != field_set:
            needs_rewrite = True
        normalized_rows.append(normalized)
    normalized_rows = refresh_original_token_counts(normalized_rows)
    if needs_rewrite:
        with csv_path.open('w', encoding='utf-8', newline='') as handle:
            writer = csv.DictWriter(handle, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerows(normalized_rows)
    return normalized_rows


def load_rows(csv_path: Path):
    with csv_path.open('r', encoding='utf-8', newline='') as handle:
        reader = csv.DictReader(handle)
        return list(reader)


def write_rows(csv_path: Path, rows: Iterable[dict]):
    rows = list(rows)
    rows = refresh_original_token_counts(rows)
    tmp = tempfile.NamedTemporaryFile('w', delete=False, encoding='utf-8', newline='')
    try:
        writer = csv.DictWriter(tmp, fieldnames=FIELDNAMES)
        writer.writeheader()
        writer.writerows(rows)
    finally:
        tmp.close()
    shutil.move(tmp.name, csv_path)


def count_tokens(text: str) -> int:
    if not text:
        return 0
    return len(TOKENIZER.encode(text, add_special_tokens=False))


def refresh_original_token_counts(rows: Iterable[dict]):
    refreshed = []
    for row in rows:
        original = (row.get('original') or '').strip()
        row = dict(row)
        row['original_token_count'] = str(count_tokens(original))
        refreshed.append(row)
    return refreshed


def batched(iterable, size: int):
    iterator = iter(iterable)
    while True:
        batch = list(islice(iterator, size))
        if not batch:
            break
        yield batch


def extract_output_text(response):
    raw_text = getattr(response, 'output_text', None)
    if raw_text:
        return raw_text.strip()
    fragments = []
    for item in getattr(response, 'output', []) or []:
        for fragment in getattr(item, 'content', []) or []:
            fragment_type = fragment.get('type') if isinstance(fragment, dict) else getattr(fragment, 'type', None)
            if fragment_type == 'output_text':
                if isinstance(fragment, dict):
                    fragments.append(fragment.get('text', ''))
                else:
                    fragments.append(getattr(fragment, 'text', '') or '')
    return ''.join(fragments).strip()


def call_model(prompt_text: str):
    messages: tuple[dict[str, str], ...] = (
        {
            'role': 'system',
            'content': SYSTEM_PROMPT,
        },
        {
            'role': 'user',
            'content': f"""Original prompt:
{prompt_text}

First craft the two variants, then produce the compressed prompt. Return only the JSON object with the required keys.""",
        },
    )
    client = get_client()
    last_error: Exception | None = None
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            response = client.responses.parse(
                model=MODEL_NAME,
                input=messages,
                reasoning={'effort': REASONING_EFFORT},
                text={'verbosity': VERBOSITY},
                max_output_tokens=MAX_OUTPUT_TOKENS,
                text_format=PromptVariants,
            )
            raw_text = extract_output_text(response)
            parsed = response.output_parsed
            if parsed is None:
                if not raw_text:
                    raise RuntimeError('Model returned no text to parse for structured output.')
                parsed = PromptVariants.model_validate_json(raw_text)
            return parsed, raw_text
        except Exception as err:
            last_error = err
            wait_for = RETRY_BACKOFF_SECONDS * attempt
            print(f'Attempt {attempt} failed ({err}). Retrying in {wait_for:.1f}s...')
            time.sleep(wait_for)
    raise RuntimeError(f'Failed to generate compression after {MAX_RETRIES} attempts: {last_error}')


def process_dataset(limit: int | None = None):
    rows = ensure_csv_schema(CSV_PATH, FIELDNAMES)
    total_rows = len(rows)
    pending_total = sum(1 for row in rows if not (row.get('compressed_prompt') or '').strip())
    if PROCESS_ONLY_PENDING:
        target_rows = [(idx, row) for idx, row in enumerate(rows) if not (row.get('compressed_prompt') or '').strip()]
    else:
        target_rows = list(enumerate(rows))
    print(f'Total rows: {total_rows} | Pending: {pending_total}')
    if limit is not None:
        target_rows = target_rows[:limit]
        print(f'Processing up to {len(target_rows)} rows (limit={limit}).')
    if not target_rows:
        print('Nothing to do!')
        return

    processed = 0
    max_workers = min(MAX_WORKERS, len(target_rows)) or 1
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        for batch in batched(target_rows, BATCH_SIZE):
            print(f'Submitting batch of {len(batch)} prompts (starting row {batch[0][0] + 1}).')
            futures = {
                executor.submit(call_model, (row.get('original') or '').strip()): (row_idx, row)
                for row_idx, row in batch
            }
            for future in as_completed(futures):
                row_idx, row = futures[future]
                original_prompt = (row.get('original') or '').strip()
                try:
                    parsed, raw_content = future.result()
                except Exception as err:
                    raise RuntimeError(f'Row {row_idx + 1} failed after retries: {err}') from err
                data = parsed.model_dump()
                compressed = data.get('compressed_prompt') or original_prompt
                row['compressed_prompt'] = compressed
                row['compressed_token_count'] = str(count_tokens(compressed))
                row['uncompressed_alt_one'] = data.get('uncompressed_alt_one', '')
                row['uncompressed_alt_two'] = data.get('uncompressed_alt_two', '')
                processed += 1
                print(f"Row {row_idx + 1}: compressed tokens {row['compressed_token_count']} | Raw response: {raw_content[:120]}...")
                if processed % FLUSH_EVERY == 0:
                    write_rows(CSV_PATH, rows)
                    print(f'Progress saved through row {row_idx + 1}. Processed so far: {processed}.')
            write_rows(CSV_PATH, rows)
            print(f'Progress saved through row {batch[-1][0] + 1}. Processed so far: {processed}.')
    write_rows(CSV_PATH, rows)
    print(f'Run complete. Processed {processed} rows.')

# %%
# Alternative helpers: compression only (no stylistic variants)

COMPRESS_ONLY_SYSTEM_PROMPT = """You are PromptCompressor, an expert at compressing prompts for downstream LLMs while preserving every constraint.

Workflow:
1. Read the original prompt carefully.
2. Come up with a shorter version of the prompt that conveys the same meaning as the original, with no loss of semantic context.

Compression rules:
- Strip trailing punctuation (question marks, exclamation points, ellipses, periods) at the end of the prompt.
- Reduce fluff words - 'of', 'a', 'the', 'an', etc - wherever possible
- Drop optional articles, helper verbs, fillers, or polite wording when they are not required for meaning.
- Preserve entities, dates, numbers, units, modality, polarity, and ordering exactly.
- Prefer minimal punctuation overall; use simple separators such as semicolons only when grouping is ambiguous.

Examples:

Who was Kyle Van Zyl playing against when he scored 36 of hisa teams 61 points? -> Who was Kyle Van Zyl playing when he scored 36 of teams 61 points
From the passage list down the areas for which Dar es Salaam is Tanzania's most prominent city. List the results in comma separated format -> From passage list areas where Dar es Salaam is Tanzania's most prominent city list results comma separated
What is a polygon? -> What is a polygon
Which episodes of season four of Game of Thrones did Michelle MacLaren direct? -> season four episodes Game of Thrones did Michelle MacLaren direct
What is process mining -> What is process mining
What are some unique curtain tie backs that you can make yourself -> list unique curtain tie backs you can make yourself
Who gave the UN the land in NY to build their HQ? -> Who gave UN land in NY to build HQ
"""


class CompressedPromptOnly(BaseModel):
    compressed_prompt: str


def call_model_compression_only(prompt_text: str):
    messages: tuple[dict[str, str], ...] = (
        {
            'role': 'system',
            'content': COMPRESS_ONLY_SYSTEM_PROMPT,
        },
        {
            'role': 'user',
            'content': f"""Original prompt:
{prompt_text}

Return only JSON with key compressed_prompt.""",
        },
    )
    client = get_client()
    last_error: Exception | None = None
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            response = client.responses.parse(
                model=MODEL_NAME,
                input=messages,
                reasoning={'effort': REASONING_EFFORT},
                text={'verbosity': VERBOSITY},
                max_output_tokens=MAX_OUTPUT_TOKENS,
                text_format=CompressedPromptOnly,
            )
            raw_text = extract_output_text(response)
            parsed = response.output_parsed
            if parsed is None:
                if not raw_text:
                    raise RuntimeError('Model returned no text to parse for compression-only output.')
                parsed = CompressedPromptOnly.model_validate_json(raw_text)
            return parsed, raw_text
        except Exception as err:
            last_error = err
            wait_for = RETRY_BACKOFF_SECONDS * attempt
            print(f'Attempt {attempt} failed ({err}). Retrying in {wait_for:.1f}s...')
            time.sleep(wait_for)
    raise RuntimeError(f'Compression-only call failed after {MAX_RETRIES} attempts: {last_error}')


# Just process and add compression columns to the CSV, assuming extra columns may exist

def process_dataset_compression_only(limit: int | None = None):
    import csv
    from pathlib import Path
    rows = []
    with open(CSV_PATH, 'r', encoding='utf-8', newline='') as handle:
        reader = csv.DictReader(handle)
        for row in reader:
            rows.append(row)
    total_rows = len(rows)
    pending_total = sum(1 for row in rows if not (row.get('compressed_prompt') or '').strip())
    if PROCESS_ONLY_PENDING:
        target_rows = [(idx, row) for idx, row in enumerate(rows) if not (row.get('compressed_prompt') or '').strip()]
    else:
        target_rows = list(enumerate(rows))
    print(f'Total rows: {total_rows} | Pending: {pending_total}')
    if limit is not None:
        target_rows = target_rows[:limit]
        print(f'Processing up to {len(target_rows)} rows (limit={limit}).')
    if not target_rows:
        print('Nothing to do!')
        return

    processed = 0
    from concurrent.futures import ThreadPoolExecutor, as_completed
    max_workers = min(MAX_WORKERS, len(target_rows)) or 1
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        for batch in batched(target_rows, BATCH_SIZE):
            print(f'Submitting batch of {len(batch)} prompts (starting row {batch[0][0] + 1}).')
            futures = {
                executor.submit(call_model_compression_only, (row.get('original') or '').strip()): (row_idx, row)
                for row_idx, row in batch
            }
            for future in as_completed(futures):
                row_idx, row = futures[future]
                original_prompt = (row.get('original') or '').strip()
                try:
                    parsed, raw_content = future.result()
                except Exception as err:
                    raise RuntimeError(f'Row {row_idx + 1} failed after retries: {err}') from err
                data = parsed.model_dump()
                compressed = data.get('compressed_prompt') or original_prompt
                row['compressed_prompt'] = compressed
                row['compressed_token_count'] = str(count_tokens(compressed))
                processed += 1
                print(f"Row {row_idx + 1}: compressed tokens {row['compressed_token_count']} | Raw response: {raw_content[:120]}...")
                if processed % FLUSH_EVERY == 0:
                    # Write all columns, even if extra ones exist
                    with open(CSV_PATH, 'w', encoding='utf-8', newline='') as handle:
                        writer = csv.DictWriter(handle, fieldnames=rows[0].keys())
                        writer.writeheader()
                        writer.writerows(rows)
                    print(f'Progress saved through row {row_idx + 1}. Processed so far: {processed}.')
            with open(CSV_PATH, 'w', encoding='utf-8', newline='') as handle:
                writer = csv.DictWriter(handle, fieldnames=rows[0].keys())
                writer.writeheader()
                writer.writerows(rows)
            print(f'Progress saved through row {batch[-1][0] + 1}. Processed so far: {processed}.')
    with open(CSV_PATH, 'w', encoding='utf-8', newline='') as handle:
        writer = csv.DictWriter(handle, fieldnames=rows[0].keys())
        writer.writeheader()
        writer.writerows(rows)
    print(f'Compression-only run complete. Processed {processed} rows.')

# %%
process_dataset_compression_only(limit=LIMIT)
# Out:
# Total rows: 14609 | Pending: 14589
# Processing up to 100 rows (limit=100).
# Submitting batch of 6 prompts (starting row 21).
# Row 21: compressed tokens 8 | Raw response: {"compressed_prompt":"Give me top 5 golf equipment company names"}...
# Row 23: compressed tokens 12 | Raw response: {"compressed_prompt":"Which Dutch artist painted Girl with a Pearl Earring"}...
# Row 25: compressed tokens 3 | Raw response: {"compressed_prompt":"What is verb"}...
# Row 26: compressed tokens 27 | Raw response: {"compressed_prompt":"Extract owner of Lamborghini and listing of different types of Huracan cars Lamborghini has produc...
# Row 22: compressed tokens 9 | Raw response: {"compressed_prompt":"Who has won the most Olympic gold medals"}...
# Progress saved through row 22. Processed so far: 5.
# Row 24: compressed tokens 7 | Raw response: {"compressed_prompt":"What happens when the sun goes down"}...
# Progress saved through row 26. Processed so far: 6.
# Submitting batch of 6 prompts (starting row 27).
# Row 30: compressed tokens 9 | Raw response: {"compressed_prompt":"Who became king of Holland in 1806"}...
# Row 32: compressed tokens 12 | Raw response: {"compressed_prompt":"Who played Billy the Kid in The Left Handed Gun"}...
# Row 31: compressed tokens 6 | Raw response: {"compressed_prompt":"What is best PlayStation or Xbox"}...
# Row 27: compressed tokens 30 | Raw response: {"compressed_prompt":"Which of these are useful for transportation: glass of wine, lamp, train, iced cube tray, plane, b...
# Progress saved through row 27. Processed so far: 10.
# Row 29: compressed tokens 11 | Raw response: {"compressed_prompt":"What is the average lifespan of a Golden Retriever"}...
# Row 28: compressed tokens 14 | Raw response: {"compressed_prompt":"Identify whether Panduri or Zurna string or woodwind"}...
# Progress saved through row 32. Processed so far: 12.
# Submitting batch of 6 prompts (starting row 33).
# Row 35: compressed tokens 4 | Raw response: {"compressed_prompt":"What is underwriting"}...
# Row 36: compressed tokens 8 | Raw response: {"compressed_prompt":"List characteristics of a good coffee shop"}...
# Row 34: compressed tokens 5 | Raw response: {"compressed_prompt":"What is REST API"}...
# Progress saved through row 34. Processed so far: 15.
# Row 37: compressed tokens 6 | Raw response: {"compressed_prompt":"Summarize what LinkedIn does"}...
# Row 38: compressed tokens 9 | Raw response: {"compressed_prompt":"Who saved Andromeda from sea monster"}...
# Row 33: compressed tokens 8 | Raw response: {"compressed_prompt":"why did Syd Barrett leave Pink Floyd"}...
# Progress saved through row 38. Processed so far: 18.
# Submitting batch of 6 prompts (starting row 39).
# Row 44: compressed tokens 5 | Raw response: {"compressed_prompt":"Did dinosaurs have lips"}...
# Row 42: compressed tokens 5 | Raw response: {"compressed_prompt":"When was the wheel invented"}...
# Progress saved through row 42. Processed so far: 20.
# Row 43: compressed tokens 7 | Raw response: {"compressed_prompt":"Scene between two actors discussing Inception"}...
# Row 39: compressed tokens 6 | Raw response: {"compressed_prompt":"How can I contribute to Spark"}...
# Row 41: compressed tokens 30 | Raw response: {"compressed_prompt":"Using examples from the text summarize main arguments in favor of slavery reparations in the Unite...
# Row 40: compressed tokens 5 | Raw response: {"compressed_prompt":"Who are The Lumières"}...
# Progress saved through row 44. Processed so far: 24.
# Submitting batch of 6 prompts (starting row 45).
# Row 46: compressed tokens 5 | Raw response: {"compressed_prompt":"What is Sunshine Recession"}...
# Progress saved through row 46. Processed so far: 25.
# Row 48: compressed tokens 9 | Raw response: {"compressed_prompt":"What is the best TV series in the world"}...
# Row 45: compressed tokens 8 | Raw response: {"compressed_prompt":"Are lilies safe for cats"}...
# Row 47: compressed tokens 7 | Raw response: {"compressed_prompt":"What currency is used in the Netherlands"}...
# Row 50: compressed tokens 7 | Raw response: {"compressed_prompt":"List harness types used in rock climbing"}...
# Row 49: compressed tokens 10 | Raw response: {"compressed_prompt":"Who was first to record Needles and Pins song"}...
# Progress saved through row 49. Processed so far: 30.
# Progress saved through row 50. Processed so far: 30.
# Submitting batch of 6 prompts (starting row 51).
# Row 52: compressed tokens 12 | Raw response: {"compressed_prompt":"In ASOIAF, who founded House Karstark"}...
# Row 51: compressed tokens 10 | Raw response: {"compressed_prompt":"Suggest family rules to promote healthy family relationships"}...
# Row 53: compressed tokens 13 | Raw response: {"compressed_prompt":"What is enriched air and why divers dive with enriched air"}...
# Row 54: compressed tokens 9 | Raw response: {"compressed_prompt":"What film won the 1943 Oscar for Best Picture"}...
# Row 55: compressed tokens 9 | Raw response: {"compressed_prompt":"which weighs more, cold or hot water"}...
# Progress saved through row 55. Processed so far: 35.
# Row 56: compressed tokens 22 | Raw response: {"compressed_prompt":"Given paragraph, top speed of Kia Stinger; Return only JSON with key compressed_prompt"}...
# Progress saved through row 56. Processed so far: 36.
# Submitting batch of 6 prompts (starting row 57).
# Row 61: compressed tokens 4 | Raw response: {"compressed_prompt":"What is LAPR"}...
# Row 58: compressed tokens 10 | Raw response: {"compressed_prompt":"What is your favorite Calvin and Hobbes strip"}...
# Row 62: compressed tokens 6 | Raw response: {"compressed_prompt":"Is beauty objective or subjective"}...
# Row 59: compressed tokens 6 | Raw response: {"compressed_prompt":"What makes Formula One car fast"}...
# Progress saved through row 59. Processed so far: 40.
# Row 57: compressed tokens 20 | Raw response: {"compressed_prompt":"Write a short paragraph why you should not have both a pet cat and a pet bird"}...
# Row 60: compressed tokens 12 | Raw response: {"compressed_prompt":"Summarize history of Key Lime Pie without direct quotes"}...
# Progress saved through row 62. Processed so far: 42.
# Submitting batch of 6 prompts (starting row 63).
# Row 67: compressed tokens 17 | Raw response: {"compressed_prompt":"Does outbreeding or inbreeding benefit the offspring more"}...
# Row 63: compressed tokens 16 | Raw response: {"compressed_prompt":"Which instrument is string or percussion: Kpanlogo, Shamisen"}...
# Row 64: compressed tokens 11 | Raw response: {"compressed_prompt":"Why do potato chip bags become stale after opening"}...
# Progress saved through row 64. Processed so far: 45.
# Row 68: compressed tokens 6 | Raw response: {"compressed_prompt":"What is the future for human"}...
# Row 65: compressed tokens 11 | Raw response: {"compressed_prompt":"Classify each of the following as primary or secondary color"}...
# Row 66: compressed tokens 17 | Raw response: {"compressed_prompt":"Where are British Virgin Islands (BVI) and which islands are part of BVI"}...
# Progress saved through row 68. Processed so far: 48.
# Submitting batch of 6 prompts (starting row 69).
# Row 69: compressed tokens 13 | Raw response: {"compressed_prompt":"Name some bravolebrities from Vanderpump Rules"}...
# Row 71: compressed tokens 9 | Raw response: {"compressed_prompt":"Who is Muhammad Ejaz Shafi"}...
# Progress saved through row 71. Processed so far: 50.
# Row 70: compressed tokens 8 | Raw response: {"compressed_prompt":"Name famous rock bands from the 1960s"}...
# Row 73: compressed tokens 5 | Raw response: {"compressed_prompt":"Who are the Smiths"}...
# Row 72: compressed tokens 4 | Raw response: {"compressed_prompt":"Who invented the telephone"}...
# Row 74: compressed tokens 11 | Raw response: {"compressed_prompt":"Five ways to make my homebrew beer more interesting"}...
# Progress saved through row 74. Processed so far: 54.
# Submitting batch of 6 prompts (starting row 75).
# Row 77: compressed tokens 4 | Raw response: {"compressed_prompt":"What is HiFI"}...
# Progress saved through row 77. Processed so far: 55.
# Row 75: compressed tokens 10 | Raw response: {"compressed_prompt":"How many Grammy Awards has Bad Bunny won"}...
# Row 76: compressed tokens 8 | Raw response: {"compressed_prompt":"When was the first Reading railway station opened"}...
# Row 79: compressed tokens 16 | Raw response: {"compressed_prompt":"Which of these are rappers Eminem Michael Jackson Rihanna 50 Cent"}...
# Row 78: compressed tokens 15 | Raw response: {"compressed_prompt":"What is a brown eared pheasant"}...
# Row 80: compressed tokens 12 | Raw response: {"compressed_prompt":"Did Lewis Hamilton win the F1 championship in his first season"}...
# Progress saved through row 80. Processed so far: 60.
# Progress saved through row 80. Processed so far: 60.
# Submitting batch of 6 prompts (starting row 81).
# Row 82: compressed tokens 9 | Raw response: {"compressed_prompt":"What are the most common injuries in rowing"}...
# Row 81: compressed tokens 7 | Raw response: {"compressed_prompt":"types of embroidery stitches for writing letters"}...
# Row 86: compressed tokens 13 | Raw response: {"compressed_prompt":"What is a good way to get around without a car"}...
# Row 85: compressed tokens 28 | Raw response: {"compressed_prompt":"Given a paragraph about Billie Eilish, tell me who produced her debut single and what is her chart...
# Row 84: compressed tokens 44 | Raw response: {"compressed_prompt":"Classify equipment by sport used: basketball, football, or soccer; shin guards, shooting sleeve, p...
# Progress saved through row 84. Processed so far: 65.
# Row 83: compressed tokens 6 | Raw response: {"compressed_prompt":"What is a kite"}...
# Progress saved through row 86. Processed so far: 66.
# Submitting batch of 6 prompts (starting row 87).
# Row 90: compressed tokens 6 | Raw response: {"compressed_prompt":"Who was boxer John Baldwin"}...
# Row 91: compressed tokens 15 | Raw response: {"compressed_prompt":"Identify string or percussion instrument: Samphor, Viola toeria"}...
# Row 88: compressed tokens 12 | Raw response: {"compressed_prompt":"Why is Santa Cruz, California a great place to live"}...
# Row 87: compressed tokens 20 | Raw response: {"compressed_prompt":"Identify alive or extinct animal species: Palaeophis, Giant Tortoise"}...
# Progress saved through row 87. Processed so far: 70.
# Row 89: compressed tokens 6 | Raw response: {"compressed_prompt":"Give ideas to manage my manager"}...
# Row 92: compressed tokens 33 | Raw response: {"compressed_prompt":"If we played a game identifying things found inside a house which of these would we call out: car,...
# Progress saved through row 92. Processed so far: 72.
# Submitting batch of 6 prompts (starting row 93).
# Row 94: compressed tokens 18 | Raw response: {"compressed_prompt":"Give me bulleted list of 5 highest mountains in world and their heights in meters"}...
# Row 93: compressed tokens 30 | Raw response: {"compressed_prompt":"Classify as dark-colored or light-colored beers: porter, pilsner, stout, amber, lager"}...
# Row 96: compressed tokens 4 | Raw response: {"compressed_prompt":"Which products apple sell"}...
# Progress saved through row 96. Processed so far: 75.
# Row 98: compressed tokens 9 | Raw response: {"compressed_prompt":"Describe what oil is and list its applications"}...
# Row 95: compressed tokens 38 | Raw response: {"compressed_prompt":"Extract all dates mentioned in this paragraph; list them in bullets in format {Date} - {Descriptio...
# Row 97: compressed tokens 22 | Raw response: {"compressed_prompt":"Write short story about a person discovering hidden room in house; include plot twist; provide cle...
# Progress saved through row 98. Processed so far: 78.
# Submitting batch of 6 prompts (starting row 99).
# Row 99: compressed tokens 8 | Raw response: {"compressed_prompt":"List 6 different types of rain in Seattle"}...
# Row 103: compressed tokens 10 | Raw response: {"compressed_prompt":"How much music theory knowledge is required to compose music"}...
# Progress saved through row 103. Processed so far: 80.
# Row 101: compressed tokens 13 | Raw response: {"compressed_prompt":"I started a new company Greystone Inc what do we do"}...
# Row 100: compressed tokens 4 | Raw response: {"compressed_prompt":"What is investment banking"}...
# Row 102: compressed tokens 18 | Raw response: {"compressed_prompt":"Tell me which of these foods are on EWG's Dirty Dozen list"}...
# Row 104: compressed tokens 35 | Raw response: {"compressed_prompt":"Categorize each of the following instruments as either string or keyboard: Guitar, Violin, piano, ...
# Progress saved through row 104. Processed so far: 84.
# Submitting batch of 6 prompts (starting row 105).
# Row 108: compressed tokens 10 | Raw response: {"compressed_prompt":"What is the tallest mountain in the continental US"}...
# Progress saved through row 108. Processed so far: 85.
# Row 109: compressed tokens 7 | Raw response: {"compressed_prompt":"Who is Shoji Hashimoto"}...
# Row 107: compressed tokens 20 | Raw response: {"compressed_prompt":"Change following passage to past tense; return only JSON with key compressed_prompt"}...
# Row 106: compressed tokens 15 | Raw response: {"compressed_prompt":"What is Maareech Advanced Torpedo Defence System (ATDS)"}...
# Row 105: compressed tokens 13 | Raw response: {"compressed_prompt":"Summarize in one sentence the article about a famous song"}...
# Row 110: compressed tokens 7 | Raw response: {"compressed_prompt":"What are best 1980s comedy movies"}...
# Progress saved through row 110. Processed so far: 90.
# Progress saved through row 110. Processed so far: 90.
# Submitting batch of 6 prompts (starting row 111).
# Row 111: compressed tokens 11 | Raw response: {"compressed_prompt":"In golf what do Americans call an albatross"}...
# Row 112: compressed tokens 10 | Raw response: {"compressed_prompt":"What are common ingredients of a Full English breakfast"}...
# Row 114: compressed tokens 11 | Raw response: {"compressed_prompt":"How to operate a car with a manual transmission"}...
# Row 116: compressed tokens 11 | Raw response: {"compressed_prompt":"What are 5 uses for an empty La Croix can"}...
# Row 113: compressed tokens 15 | Raw response: {"compressed_prompt":"Plan three day road trip for May long weekend from Westfield, New Jersey"}...
# Progress saved through row 113. Processed so far: 95.
# Row 115: compressed tokens 26 | Raw response: {"compressed_prompt":"What is Research Collaboratory for Structural Bioinformatics Protein Data Bank (RCSB PDB)"}...
# Progress saved through row 116. Processed so far: 96.
# Submitting batch of 4 prompts (starting row 117).
# Row 120: compressed tokens 4 | Raw response: {"compressed_prompt":"What is SVM"}...
# Row 118: compressed tokens 12 | Raw response: {"compressed_prompt":"Why are many U.S. Hollywood films made in Georgia"}...
# Row 119: compressed tokens 6 | Raw response: {"compressed_prompt":"How many managers has Arsenal had"}...
# Row 117: compressed tokens 24 | Raw response: {"compressed_prompt":"What is the name of Winslow's nerdy next-door neighbor on TV show Family Matters"}...
# Progress saved through row 117. Processed so far: 100.
# Progress saved through row 120. Processed so far: 100.
# Compression-only run complete. Processed 100 rows.

# %%
# Optional: inspect a few rows after processing
# import pandas as pd
# df = pd.read_csv(CSV_PATH)
# df.head()

# Test a single compression prompt and print the full API response for troubleshooting
example_prompt = "Summarize the following review: The food was great but the service was slow."
try:
    messages = [
        {'role': 'system', 'content': COMPRESS_ONLY_SYSTEM_PROMPT},
        {'role': 'user', 'content': f"""Original prompt:\n{example_prompt}\n\nReturn only JSON with key compressed_prompt."""}
    ]
    client = get_client()
    response = client.responses.parse(
        model=MODEL_NAME,
        input=messages,
        reasoning={'effort': REASONING_EFFORT},
        text={'verbosity': VERBOSITY},
        max_output_tokens=MAX_OUTPUT_TOKENS,
        text_format=CompressedPromptOnly,
    )
    print("[TEST] Full API response:", response)
    raw_text = extract_output_text(response)
    print("[TEST] Raw model response:", raw_text)
    parsed = response.output_parsed
    print("[TEST] Parsed output:", parsed)
except Exception as e:
    print("[TEST] Exception during single prompt test:", e)
# Out:
# [TEST] Full API response: ParsedResponse[CompressedPromptOnly](id='resp_0f492f7d6c6a72d70068fabe5cc838819c8b1e51e3ef15aa7e', created_at=1761263196.0, error=None, incomplete_details=IncompleteDetails(reason='max_output_tokens'), instructions=None, metadata={}, model='gpt-5-nano-2025-08-07', object='response', output=[ResponseReasoningItem(id='rs_0f492f7d6c6a72d70068fabe5d285c819c88595c1c83fe8bd6', summary=[], type='reasoning', content=None, encrypted_content=None, status=None)], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=128, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort='medium', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='incomplete', text=ResponseTextConfig(format=ResponseFormatTextJSONSchemaConfig(name='CompressedPromptOnly', schema_={'properties': {'compressed_prompt': {'title': 'Compressed Prompt', 'type': 'string'}}, 'required': ['compressed_prompt'], 'title': 'CompressedPromptOnly', 'type': 'object', 'additionalProperties': False}, type='json_schema', description=None, strict=True), verbosity='low'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=248, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=128, output_tokens_details=OutputTokensDetails(reasoning_tokens=128), total_tokens=376), user=None, billing={'payer': 'developer'}, store=True)
# [TEST] Raw model response:
# [TEST] Parsed output: None

# %%
# Analyze first 120 rows for token savings, filtering out rows with original_token_count > 64
import csv
from pathlib import Path
import pandas as pd

CSV_PATH = Path('training_data/very-short-prompt-dolly-data.csv')

# Load first 120 rows
with CSV_PATH.open('r', encoding='utf-8', newline='') as handle:
    reader = csv.DictReader(handle)
    rows = [row for _, row in zip(range(120), reader)]

# Filter rows with original_token_count <= 64
filtered_rows = [row for row in rows if int(row.get('original_token_count', 0)) <= 64]

total_original_tokens = sum(int(row.get('original_token_count', 0)) for row in filtered_rows)
total_compressed_tokens = sum(int(row.get('compressed_token_count', 0)) for row in filtered_rows)

if total_original_tokens > 0:
    savings_pct = 100 * (1 - total_compressed_tokens / total_original_tokens)
else:
    savings_pct = 0.0

print(f"First 120 rows (filtered, original_token_count <= 64):")
print(f"Total original tokens: {total_original_tokens}")
print(f"Total compressed tokens: {total_compressed_tokens}")
print(f"Overall savings: {savings_pct:.2f}%")

# Compare first 120 rows (with <=64 tokens) from both CSVs, calculate token counts and compression ratio
import csv
from pathlib import Path
from transformers import AutoTokenizer

# Paths
SOURCE_CSV = Path('training_data/dolly-summarization-data-rouge.csv')
COMPRESSED_CSV = Path('training_data/very-short-prompt-dolly-data.csv')

# Load tokenizer (same logic as elsewhere in notebook)
TOKENIZER_PATH = Path('/Users/dotslashderek/workspace/Gravitee/small-prompt-compression')
FALLBACK_TOKENIZER_NAME = 'dotslashderek/short-prompt-compressor'
if TOKENIZER_PATH.exists():
    tokenizer = AutoTokenizer.from_pretrained(str(TOKENIZER_PATH), use_fast=True)
else:
    tokenizer = AutoTokenizer.from_pretrained(FALLBACK_TOKENIZER_NAME, use_fast=True)

def count_tokens(text):
    if not text:
        return 0
    return len(tokenizer.encode(text, add_special_tokens=False))

# Step 1: Load and filter first 150 rows from both files, keep only those with <=64 tokens (on the fly), select first 120
def load_and_filter(csv_path, tokenizer, max_rows=150, max_tokens=64, select_rows=120):
    filtered = []
    with csv_path.open('r', encoding='utf-8', newline='') as handle:
        reader = csv.DictReader(handle)
        for row in reader:
            orig = (row.get('original') or '').strip()
            orig_tokens = count_tokens(orig)
            if orig_tokens <= max_tokens:
                row['original_token_count_actual'] = orig_tokens
                filtered.append(row)
            if len(filtered) >= select_rows:
                break
            if len(filtered) + (max_rows - len(filtered)) < select_rows:
                # If not enough rows left to reach select_rows after filtering, break early
                break
    return filtered[:select_rows]

filtered_rows_a = load_and_filter(SOURCE_CSV, tokenizer)
filtered_rows_b = load_and_filter(COMPRESSED_CSV, tokenizer)

# Step 2: Compare and calculate token counts for both approaches
print(f"Comparing first 120 rows with <=64 tokens from both files (each is a different compression approach):")
print(f"{'Idx':>3} | {'A Orig':<40} | {'A OrigTok':>8} | {'A Compr':<40} | {'A CompTok':>8} | {'B Orig':<40} | {'B OrigTok':>8} | {'B Compr':<40} | {'B CompTok':>8}")
print('-'*200)
total_a_orig = total_a_comp = total_b_orig = total_b_comp = 0
for idx, (row_a, row_b) in enumerate(zip(filtered_rows_a, filtered_rows_b), 1):
    a_orig = (row_a.get('original') or '').strip()
    a_orig_tok = count_tokens(a_orig)
    a_comp = (row_a.get('compressed') or row_a.get('compressed_prompt') or '').strip()
    a_comp_tok = count_tokens(a_comp)
    b_orig = (row_b.get('original') or '').strip()
    b_orig_tok = count_tokens(b_orig)
    b_comp = (row_b.get('compressed') or row_b.get('compressed_prompt') or '').strip()
    b_comp_tok = count_tokens(b_comp)
    total_a_orig += a_orig_tok
    total_a_comp += a_comp_tok
    total_b_orig += b_orig_tok
    total_b_comp += b_comp_tok
    print(f"{idx:3} | {a_orig[:40]:<40} | {a_orig_tok:8} | {a_comp[:40]:<40} | {a_comp_tok:8} | {b_orig[:40]:<40} | {b_orig_tok:8} | {b_comp[:40]:<40} | {b_comp_tok:8}")

print('-'*200)
print(f"Totals:")
print(f"A: Original tokens: {total_a_orig} | Compressed tokens: {total_a_comp}")
print(f"B: Original tokens: {total_b_orig} | Compressed tokens: {total_b_comp}")
if total_a_orig > 0:
    savings_a = 100 * (1 - total_a_comp / total_a_orig)
    print(f"A: Compression ratio: {total_a_comp/total_a_orig:.2f} | Savings: {savings_a:.2f}%")
else:
    print("A: No tokens in original column.")
if total_b_orig > 0:
    savings_b = 100 * (1 - total_b_comp / total_b_orig)
    print(f"B: Compression ratio: {total_b_comp/total_b_orig:.2f} | Savings: {savings_b:.2f}%")
else:
    print("B: No tokens in original column.")

# After the previous comparison, filter and display rows where A's compressed prompt is shorter than B's
shorter_in_a = []
for idx, (row_a, row_b) in enumerate(zip(filtered_rows_a, filtered_rows_b), 1):
    a_comp = (row_a.get('compressed') or row_a.get('compressed_prompt') or '').strip()
    a_comp_tok = count_tokens(a_comp)
    b_comp = (row_b.get('compressed') or row_b.get('compressed_prompt') or '').strip()
    b_comp_tok = count_tokens(b_comp)
    if a_comp_tok < b_comp_tok:
        shorter_in_a.append((idx, row_a, row_b, a_comp_tok, b_comp_tok))

print(f"\nRows where A's compressed prompt is shorter than B's:")
print(f"{'Idx':>3} | {'A Orig':<40} | {'A Compr':<40} | {'A CompTok':>8} | {'B Compr':<40} | {'B CompTok':>8}")
print('-'*160)
for idx, row_a, row_b, a_comp_tok, b_comp_tok in shorter_in_a:
    a_orig = (row_a.get('original') or '').strip()
    a_comp = (row_a.get('compressed') or row_a.get('compressed_prompt') or '').strip()
    b_comp = (row_b.get('compressed') or row_b.get('compressed_prompt') or '').strip()
    print(f"{idx:3} | {a_orig[:200]:<200} | {a_comp[:200]:<200} | {a_comp_tok:8} | {b_comp[:200]:<200} | {b_comp_tok:8}")
print(f"Total rows where A's compression is shorter: {len(shorter_in_a)} out of {len(filtered_rows_a)}")

# Also display rows where B's compressed prompt is shorter than A's by at least 2 tokens
shorter_in_b = []
for idx, (row_a, row_b) in enumerate(zip(filtered_rows_a, filtered_rows_b), 1):
    a_comp = (row_a.get('compressed') or row_a.get('compressed_prompt') or '').strip()
    a_comp_tok = count_tokens(a_comp)
    b_comp = (row_b.get('compressed') or row_b.get('compressed_prompt') or '').strip()
    b_comp_tok = count_tokens(b_comp)
    if b_comp_tok < a_comp_tok - 1:
        shorter_in_b.append((idx, row_a, row_b, a_comp_tok, b_comp_tok))

print(f"\nRows where B's compressed prompt is shorter than A's by at least 2 tokens:")
print(f"{'Idx':>3} | {'A Orig':<40} | {'A Compr':<40} | {'A CompTok':>8} | {'B Compr':<40} | {'B CompTok':>8}")
print('-'*160)
for idx, row_a, row_b, a_comp_tok, b_comp_tok in shorter_in_b:
    a_orig = (row_a.get('original') or '').strip()
    a_comp = (row_a.get('compressed') or row_a.get('compressed_prompt') or '').strip()
    b_comp = (row_b.get('compressed') or row_b.get('compressed_prompt') or '').strip()
    print(f"{idx:3} | {a_orig[:200]:<200} | {a_comp[:200]:<200} | {a_comp_tok:8} | {b_comp[:200]:<200} | {b_comp_tok:8}")
print(f"Total rows where B's compression is shorter by 2+: {len(shorter_in_b)} out of {len(filtered_rows_a)}")
# Out:
# First 120 rows (filtered, original_token_count <= 64):
# Total original tokens: 1769
# Total compressed tokens: 1463
# Overall savings: 17.30%
# Comparing first 120 rows with <=64 tokens from both files (each is a different compression approach):
# Idx | A Orig                                   | A OrigTok | A Compr                                  | A CompTok | B Orig                                   | B OrigTok | B Compr                                  | B CompTok
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   1 | When did Virgin Australia start operatin |        7 | When did Virgin Australia start operatin |        7 | When did Virgin Australia start operatin |        7 | When did Virgin Australia start operatin |        6
#   2 | Which is a species of fish? Tope or Rope |       13 | Which is a species of fish? Tope or Rope |       13 | Which is a species of fish? Tope or Rope |       13 | Which is a species of fish Tope or Rope  |       12
#   3 | Why can camels survive for long without  |       11 | Why can camels survive long without wate |       10 | Why can camels survive for long without  |       11 | Why can camels survive long without wate |        9
#   4 | Alice's parents have three daughters: Am |       26 | Alice's parents have three daughters: Am |       20 | Alice's parents have three daughters: Am |       26 | Alice's parents have three daughters: Am |       24
#   5 | When was Tomoaki Komorida born?          |       11 | When was Tomoaki Komorida born?          |       11 | When was Tomoaki Komorida born?          |       11 | When was Tomoaki Komorida born           |       10
#   6 | If I have more pieces at the time of sta |       18 | If I have more pieces at stalemate, do I |       15 | If I have more pieces at the time of sta |       18 | If I have more pieces at stalemate, have |       14
#   7 | Given a reference text about Lollapalooz |       26 | From a Lollapalooza reference text: wher |       21 | Given a reference text about Lollapalooz |       26 | Reference text about Lollapalooza where  |       20
#   8 | Who gave the UN the land in NY to build  |       13 | Who donated land for the UN HQ in NYC?   |       11 | Who gave the UN the land in NY to build  |       13 | Who gave UN land in NY to build HQ       |       10
#   9 | Why mobile is bad for human              |        6 | Why mobile harms humans?                 |        6 | Why mobile is bad for human              |        6 | Why mobile is bad for humans             |        6
#  10 | Who was John Moses Browning?             |        7 | Who was John Moses Browning?             |        7 | Who was John Moses Browning?             |        7 | Who was John Moses Browning              |        6
#  11 | Who is Thomas Jefferson?                 |        5 | Who is Thomas Jefferson?                 |        5 | Who is Thomas Jefferson?                 |        5 | Who is Thomas Jefferson                  |        4
#  12 | Who was Kyle Van Zyl playing against whe |       22 | Against whom did Kyle Van Zyl score 36 o |       20 | Who was Kyle Van Zyl playing against whe |       22 | Who was Kyle Van Zyl playing against whe |       20
#  13 | From the passage list down the areas for |       34 | From the passage, list areas where Dar e |       31 | From the passage list down the areas for |       34 | From the passage list areas where Dar es |       26
#  14 | What is a polygon?                       |        7 | Define polygon.                          |        5 | What is a polygon?                       |        7 | What is a polygon                        |        6
#  15 | How do I start running?                  |        6 | How to start running?                    |        5 | How do I start running?                  |        6 | How do I start running                   |        5
#  16 | Which episodes of season four of Game of |       16 | Which Season 4 GOT episodes did Michelle |       13 | Which episodes of season four of Game of |       16 | Which episodes of season four of Game of |       16
#  17 | What is process mining?                  |        5 | Process mining?                          |        3 | What is process mining?                  |        5 | What is process mining                   |        4
#  18 | What are some unique curtain tie backs t |       14 | Unique DIY curtain tie backs?            |        7 | What are some unique curtain tie backs t |       14 | What are some unique curtain tie backs t |       13
#  19 | What is a dispersive prism?              |       10 | Dispersive prism definition.             |        7 | What is a dispersive prism?              |       10 | What is a dispersive prism               |        9
#  20 | Identify which instrument is string or p |       17 | Cantaro, Gudok: string or percussion?    |       13 | Identify which instrument is string or p |       17 | Identify which instrument is string or p |       15
#  21 | Give me the top 5 golf equipment company |       10 | Top 5 golf-equipment company names       |        9 | Give me the top 5 golf equipment company |       10 | Give me top 5 golf equipment company nam |        8
#  22 | What individual has won the most Olympic |       17 | Who has the most Olympic gold medals in  |       12 | What individual has won the most Olympic |       17 | Who has won the most Olympic gold medals |        9
#  23 | Which Dutch artist painted “Girl with a  |       18 | Which Dutch artist painted “Girl with a  |       18 | Which Dutch artist painted “Girl with a  |       18 | Which Dutch artist painted Girl with a P |       12
#  24 | What happens when the sun goes down?     |        8 | What happens at sunset?                  |        5 | What happens when the sun goes down?     |        8 | What happens when the sun goes down      |        7
#  25 | What is a verb?                          |        6 | Verb?                                    |        2 | What is a verb?                          |        6 | What is verb                             |        3
#  26 | Extract the owner of Lamborghini and a l |       33 | Owner of Lamborghini; list Huracan varia |       21 | Extract the owner of Lamborghini and a l |       33 | Extract owner of Lamborghini and listing |       27
#  27 | Which of the following is useful for tra |       46 | Which items are useful for transportatio |       29 | Which of the following is useful for tra |       46 | Which of these are useful for transporta |       30
#  28 | Identify which instrument is string or w |       17 | Panduri, Zurna: string or woodwind?      |       13 | Identify which instrument is string or w |       17 | Identify whether Panduri or Zurna string |       14
#  29 | What is the average lifespan of a Golden |       12 | Golden Retriever average lifespan?       |        6 | What is the average lifespan of a Golden |       12 | What is the average lifespan of a Golden |       11
#  30 | Who became king of Holland in 1806?      |       10 | 1806 Holland king?                       |        6 | Who became king of Holland in 1806?      |       10 | Who became king of Holland in 1806       |        9
#  31 | What is best Playstation or Xbox         |        7 | What is best Playstation or Xbox         |        7 | What is best Playstation or Xbox         |        7 | What is best PlayStation or Xbox         |        6
#  32 | Who played Billy the Kid in The Left Han |       12 | The Left Handed Gun Billy the Kid actor? |       11 | Who played Billy the Kid in The Left Han |       12 | Who played Billy the Kid in The Left Han |       12
#  33 | why did Syd Barrett left the Pink Floyd? |       10 | Why did Syd Barrett leave Pink Floyd?    |        9 | why did Syd Barrett left the Pink Floyd? |       10 | why did Syd Barrett leave Pink Floyd     |        8
#  34 | what is REST API                         |        5 | REST API?                                |        4 | what is REST API                         |        5 | What is REST API                         |        5
#  35 | What is underwriting?                    |        5 | What is underwriting?                    |        5 | What is underwriting?                    |        5 | What is underwriting                     |        4
#  36 | Give me a list of some characteristics o |       15 | List some characteristics of a good coff |       10 | Give me a list of some characteristics o |       15 | List characteristics of a good coffee sh |        8
#  37 | Please summarize what Linkedin does.     |        8 | Please summarize what Linkedin does.     |        8 | Please summarize what Linkedin does.     |        8 | Summarize what LinkedIn does             |        6
#  38 | Who saved Andromeda from the sea monster |       10 | Who saved Andromeda from the sea monster |       10 | Who saved Andromeda from the sea monster |       10 | Who saved Andromeda from sea monster     |        9
#  39 | How can I contribute to Spark?           |        7 | How to contribute to Spark?              |        6 | How can I contribute to Spark?           |        7 | How can I contribute to Spark            |        6
#  40 | Who are ''The Lumières" ?                |       11 | Who are The Lumières?                    |        6 | Who are ''The Lumières" ?                |       11 | Who are The Lumières                     |        5
#  41 | Using examples taken from the text give  |       38 | From the text, summarize main arguments  |       23 | Using examples taken from the text give  |       38 | Using examples from the text summarize m |       30
#  42 | When was the wheel invented?             |        6 | Wheel invention date?                    |        4 | When was the wheel invented?             |        6 | When was the wheel invented              |        5
#  43 | write a scene between two actors discuss |       11 | Write scene between two actors discussin |        9 | write a scene between two actors discuss |       11 | Scene between two actors discussing Ince |        7
#  44 | Did dinosaurs have lips?                 |        6 | Did dinosaurs have lips?                 |        6 | Did dinosaurs have lips?                 |        6 | Did dinosaurs have lips                  |        5
#  45 | Are lilies safe for cats?                |        9 | Are lilies safe for cats?                |        9 | Are lilies safe for cats?                |        9 | Are lilies safe for cats                 |        8
#  46 | What is Sunshine Recession?              |        6 | Sunshine Recession?                      |        4 | What is Sunshine Recession?              |        6 | What is Sunshine Recession               |        5
#  47 | What is the currency in use in the Nethe |       10 | Currency used in the Netherlands?        |        6 | What is the currency in use in the Nethe |       10 | What currency is used in the Netherlands |        7
#  48 | What is the best tv series in the world  |       11 | Best TV series worldwide?                |        5 | What is the best tv series in the world  |       11 | What is the best TV series in the world  |        9
#  49 | Who was the first to record the Needles  |       13 | Who first recorded Needles and Pins?     |        8 | Who was the first to record the Needles  |       13 | Who was first to record Needles and Pins |       10
#  50 | Provide me a list of the different types |       17 | List rock climbing harness types.        |        6 | Provide me a list of the different types |       17 | List harness types used in rock climbing |        7
#  51 | Think of some family rules to promote a  |       12 | List family rules for a healthy family r |       10 | Think of some family rules to promote a  |       12 | Suggest family rules to promote healthy  |       10
#  52 | In the series A Song of Ice and Fire, wh |       20 | ASOIAF: who founded House Karstark?      |       12 | In the series A Song of Ice and Fire, wh |       20 | In ASOIAF, who founded House Karstark    |       12
#  53 | What is enriched air and why would diver |       15 | What is enriched air and why do divers u |       12 | What is enriched air and why would diver |       15 | What is enriched air and why divers dive |       13
#  54 | What film won the 1943 Oscar as best fil |        9 | 1943 Best Picture winner?                |        5 | What film won the 1943 Oscar as best fil |        9 | What film won the 1943 Oscar for Best Pi |        9
#  55 | which weighs more, cold or hot water?    |       10 | which weighs more, cold or hot water?    |       10 | which weighs more, cold or hot water?    |       10 | which weighs more, cold or hot water     |        9
#  56 | Given this paragraph, what is the top sp |       17 | Kia Stinger top speed from this paragrap |       10 | Given this paragraph, what is the top sp |       17 | Given paragraph, top speed of Kia Stinge |       22
#  57 | Write a short paragraph about why you sh |       22 | Write a short paragraph on why you shoul |       21 | Write a short paragraph about why you sh |       22 | Write a short paragraph why you should n |       20
#  58 | What is your favorite strip from the com |       14 | Your favorite Calvin and Hobbes strip?   |        9 | What is your favorite strip from the com |       14 | What is your favorite Calvin and Hobbes  |       10
#  59 | What makes a formula one car so fast?    |       10 | What makes F1 cars so fast?              |        8 | What makes a formula one car so fast?    |       10 | What makes Formula One car fast          |        6
#  60 | Without quoting directly from the text g |       23 | Summarize the history of Key Lime Pie wi |       14 | Without quoting directly from the text g |       23 | Summarize history of Key Lime Pie withou |       12
#  61 | What is LAPR?                            |        5 | What is LAPR?                            |        5 | What is LAPR?                            |        5 | What is LAPR                             |        4
#  62 | Is beauty objective or subjective?       |        7 | Is beauty objective or subjective?       |        7 | Is beauty objective or subjective?       |        7 | Is beauty objective or subjective        |        6
#  63 | Identify which instrument is string or p |       18 | String or percussion: Kpanlogo, Shamisen |       13 | Identify which instrument is string or p |       18 | Which instrument is string or percussion |       16
#  64 | Why do potato chip bags become stale aft |       12 | Why do opened potato chip bags go stale? |       11 | Why do potato chip bags become stale aft |       12 | Why do potato chip bags become stale aft |       11
#  65 | Classify each of the following as a prim |       16 | Classify each color as primary or second |        9 | Classify each of the following as a prim |       16 | Classify each of the following as primar |       11
#  66 | Where are the British Virgin Islands (BV |       22 | Where are the British Virgin Islands (BV |       19 | Where are the British Virgin Islands (BV |       22 | Where are British Virgin Islands (BVI) a |       17
#  67 | Does "outbreeding" or "inbreeding" benef |       22 | Which benefits offspring more: outbreedi |       18 | Does "outbreeding" or "inbreeding" benef |       22 | Does outbreeding or inbreeding benefit t |       17
#  68 | What is the future for human?            |        7 | Future of humanity?                      |        4 | What is the future for human?            |        7 | What is the future for human             |        6
#  69 | Name some of the bravolebrities from Van |       15 | Name Bravolebrities from Vanderpump Rule |       12 | Name some of the bravolebrities from Van |       15 | Name some bravolebrities from Vanderpump |       13
#  70 | Name some famous rock bands from the 196 |        9 | Name famous 1960s rock bands.            |        7 | Name some famous rock bands from the 196 |        9 | Name famous rock bands from the 1960s    |        8
#  71 | Who is Muhammad Ejaz Shafi               |        9 | Who is Muhammad Ejaz Shafi               |        9 | Who is Muhammad Ejaz Shafi               |        9 | Who is Muhammad Ejaz Shafi               |        9
#  72 | Who invented the telephone?              |        5 | Who invented the telephone?              |        5 | Who invented the telephone?              |        5 | Who invented the telephone               |        4
#  73 | Who are the Smiths?                      |        6 | Who are the Smiths?                      |        6 | Who are the Smiths?                      |        6 | Who are the Smiths                       |        5
#  74 | Give me five ways in which I can make my |       16 | Five ways to make my homebrew beer more  |       12 | Give me five ways in which I can make my |       16 | Five ways to make my homebrew beer more  |       11
#  75 | How many Grammy Awards has Bad Bunny won |       11 | How many Grammy Awards has Bad Bunny won |       11 | How many Grammy Awards has Bad Bunny won |       11 | How many Grammy Awards has Bad Bunny won |       10
#  76 | When was the first Reading railway stati |        9 | When was the first Reading railway stati |        9 | When was the first Reading railway stati |        9 | When was the first Reading railway stati |        8
#  77 | What is HiFI?                            |        5 | What is HiFI?                            |        5 | What is HiFI?                            |        5 | What is HiFI                             |        4
#  78 | What is a brown eared pheasant?          |       16 | Describe brown-eared pheasant?           |       14 | What is a brown eared pheasant?          |       16 | What is a brown eared pheasant           |       15
#  79 | Which of these are rappers? Eminem, Mich |       20 | Which of these are rappers? Eminem, Mich |       20 | Which of these are rappers? Eminem, Mich |       20 | Which of these are rappers Eminem Michae |       16
#  80 | Is it true that Lewis Hamilton won the c |       17 | Did Lewis Hamilton win the F1 title in h |       13 | Is it true that Lewis Hamilton won the c |       17 | Did Lewis Hamilton win the F1 championsh |       12
#  81 | What are some kinds of embroidery stitch |       11 | Lettering embroidery stitches: kinds?    |        7 | What are some kinds of embroidery stitch |       11 | types of embroidery stitches for writing |        7
#  82 | What are the most common injuries in row |       10 | Most common rowing injuries?             |        6 | What are the most common injuries in row |       10 | What are the most common injuries in row |        9
#  83 | What is a kite?                          |        7 | Define kite                              |        4 | What is a kite?                          |        7 | What is a kite                           |        6
#  84 | Classify each of the following pieces of |       58 | Identify sport (basketball, football, so |       47 | Classify each of the following pieces of |       58 | Classify equipment by sport used: basket |       44
#  85 | Given this paragraph about Billie Eilish |       31 | From this Billie Eilish paragraph, who p |       25 | Given this paragraph about Billie Eilish |       31 | Given a paragraph about Billie Eilish, t |       28
#  86 | What is a good way to get around without |       14 | Best ways to get around without a car?   |       10 | What is a good way to get around without |       14 | What is a good way to get around without |       13
#  87 | Identify which animal species is alive o |       22 | Alive or extinct: Palaeophis, Giant Tort |       17 | Identify which animal species is alive o |       22 | Identify alive or extinct animal species |       20
#  88 | Why is Santa Cruz, California a great pl |       13 | Why is Santa Cruz, California a great pl |       13 | Why is Santa Cruz, California a great pl |       13 | Why is Santa Cruz, California a great pl |       12
#  89 | Give me some ideas to manage my manager. |        9 | Ideas to manage my manager.              |        6 | Give me some ideas to manage my manager. |        9 | Give ideas to manage my manager          |        6
#  90 | Who was boxer John Baldwin               |        6 | Who was boxer John Baldwin               |        6 | Who was boxer John Baldwin               |        6 | Who was boxer John Baldwin               |        6
#  91 | Identify which instrument is string or p |       17 | String or percussion: Samphor, Viola toe |       12 | Identify which instrument is string or p |       17 | Identify string or percussion instrument |       15
#  92 | If we were playing a game where we had t |       42 | House-find game: which of these are insi |       26 | If we were playing a game where we had t |       42 | If we played a game identifying things f |       33
#  93 | Classify the following as either dark-co |       34 | Classify as dark or light beers: porter, |       26 | Classify the following as either dark-co |       34 | Classify as dark-colored or light-colore |       30
#  94 | Give me a bulleted list of the 5 highest |       23 | Bulleted list: 5 highest mountains and t |       15 | Give me a bulleted list of the 5 highest |       23 | Give me bulleted list of 5 highest mount |       18
#  95 | Extract all of the dates mentioned in th |       30 | Extract all dates in this paragraph and  |       25 | Extract all of the dates mentioned in th |       30 | Extract all dates mentioned in this para |       38
#  96 | Which products apple sell?               |        5 | Apple products?                          |        3 | Which products apple sell?               |        5 | Which products apple sell                |        4
#  97 | Write a short story about a person who d |       37 | Write a short story: a person discovers  |       33 | Write a short story about a person who d |       37 | Write short story about a person discove |       22
#  98 | Please describe  what is oil and give me |       17 | Describe oil and list its applications.  |        8 | Please describe  what is oil and give me |       17 | Describe what oil is and list its applic |        9
#  99 | List 6 different types of rain in Seattl |        8 | List 6 different Seattle rain types      |        6 | List 6 different types of rain in Seattl |        8 | List 6 different types of rain in Seattl |        8
# 100 | What is investment banking?              |        5 | What is investment banking?              |        5 | What is investment banking?              |        5 | What is investment banking               |        4
# 101 | I started a new company named Greystone  |       16 | New company Greystone Inc. What do we do |       11 | I started a new company named Greystone  |       16 | I started a new company Greystone Inc wh |       13
# 102 | Tell me whether or not these foods are o |       16 | Are these foods on the EWG Dirty Dozen l |       14 | Tell me whether or not these foods are o |       16 | Tell me which of these foods are on EWG' |       18
# 103 | How much music theory knowledge is requi |       11 | How much music theory knowledge is requi |       11 | How much music theory knowledge is requi |       11 | How much music theory knowledge is requi |       10
# 104 | Categorize each of the following instrum |       35 | Categorize as string or keyboard: Guitar |       29 | Categorize each of the following instrum |       35 | Categorize each of the following instrum |       35
# 105 | Summarize in one sentence this article a |       14 | One-sentence summary of this article abo |       14 | Summarize in one sentence this article a |       14 | Summarize in one sentence the article ab |       13
# 106 | What is the Maareech Advanced Torpedo De |       17 | Maareech Advanced Torpedo Defence System |       16 | What is the Maareech Advanced Torpedo De |       17 | What is Maareech Advanced Torpedo Defenc |       15
# 107 | Change the following passage to past ten |        9 | Change passage to past tense.            |        8 | Change the following passage to past ten |        9 | Change following passage to past tense;  |       20
# 108 | What is the tallest mountain in the cont |       11 | Tallest mountain in continental US?      |        7 | What is the tallest mountain in the cont |       11 | What is the tallest mountain in the cont |       10
# 109 | Who is Shoji Hashimoto?                  |        8 | Shoji Hashimoto?                         |        6 | Who is Shoji Hashimoto?                  |        8 | Who is Shoji Hashimoto                   |        7
# 110 | What are some of the best comedy movies  |       14 | Best 1980s comedy movies?                |        6 | What are some of the best comedy movies  |       14 | What are best 1980s comedy movies        |        7
# 111 | In golf what do the Americans call an al |       12 | In golf what do the Americans call an al |       12 | In golf what do the Americans call an al |       12 | In golf what do Americans call an albatr |       11
# 112 | What are common ingredients of a full en |       11 | Common ingredients of a Full English bre |        9 | What are common ingredients of a full en |       11 | What are common ingredients of a Full En |       10
# 113 | Plan for a three day road trip for May l |       18 | Plan for a three day road trip for May l |       18 | Plan for a three day road trip for May l |       18 | Plan three day road trip for May long we |       15
# 114 | How do you operate a car with a manual t |       13 | How to drive a manual transmission car?  |        9 | How do you operate a car with a manual t |       13 | How to operate a car with a manual trans |       11
# 115 | What is the Research Collaboratory for S |       28 | What is RCSB PDB (Research Collaboratory |       28 | What is the Research Collaboratory for S |       28 | What is Research Collaboratory for Struc |       26
# 116 | What are 5 potential uses for an empty L |       13 | List 5 uses for an empty La Croix can.   |       11 | What are 5 potential uses for an empty L |       13 | What are 5 uses for an empty La Croix ca |       11
# 117 | What is the name of the Winslow's nerdy  |       31 | Name the Winslow family's nerdy next-doo |       21 | What is the name of the Winslow's nerdy  |       31 | What is the name of Winslow's nerdy next |       24
# 118 | Why are so many US Hollywood films made  |       14 | Why are so many US Hollywood films made  |       11 | Why are so many US Hollywood films made  |       14 | Why are many U.S. Hollywood films made i |       12
# 119 | How many managers have Arsenal had?      |        7 | How many Arsenal managers?               |        5 | How many managers have Arsenal had?      |        7 | How many managers has Arsenal had        |        6
# 120 | What is SVM?                             |        5 | Explain SVM.                             |        4 | What is SVM?                             |        5 | What is SVM                              |        4
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Totals:
# A: Original tokens: 1769 | Compressed tokens: 1377
# B: Original tokens: 1769 | Compressed tokens: 1463
# A: Compression ratio: 0.78 | Savings: 22.16%
# B: Compression ratio: 0.83 | Savings: 17.30%
#
# Rows where A's compressed prompt is shorter than B's:
# Idx | A Orig                                   | A Compr                                  | A CompTok | B Compr                                  | B CompTok
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#   4 | Alice's parents have three daughters: Amy, Jessy, and what’s the name of the third daughter?                                                                                                             | Alice's parents have three daughters: Amy, Jessy, who is the third?                                                                                                                                      |       20 | Alice's parents have three daughters: Amy, Jessy, what's the name of the third daughter                                                                                                                  |       24
#  14 | What is a polygon?                                                                                                                                                                                       | Define polygon.                                                                                                                                                                                          |        5 | What is a polygon                                                                                                                                                                                        |        6
#  16 | Which episodes of season four of Game of Thrones did Michelle MacLaren direct?                                                                                                                           | Which Season 4 GOT episodes did Michelle MacLaren direct?                                                                                                                                                |       13 | Which episodes of season four of Game of Thrones did Michelle MacLaren direct?                                                                                                                           |       16
#  17 | What is process mining?                                                                                                                                                                                  | Process mining?                                                                                                                                                                                          |        3 | What is process mining                                                                                                                                                                                   |        4
#  18 | What are some unique curtain tie backs that you can make yourself?                                                                                                                                       | Unique DIY curtain tie backs?                                                                                                                                                                            |        7 | What are some unique curtain tie backs that you can make yourself                                                                                                                                        |       13
#  19 | What is a dispersive prism?                                                                                                                                                                              | Dispersive prism definition.                                                                                                                                                                             |        7 | What is a dispersive prism                                                                                                                                                                               |        9
#  20 | Identify which instrument is string or percussion: Cantaro, Gudok                                                                                                                                        | Cantaro, Gudok: string or percussion?                                                                                                                                                                    |       13 | Identify which instrument is string or percussion Cantaro Gudok                                                                                                                                          |       15
#  24 | What happens when the sun goes down?                                                                                                                                                                     | What happens at sunset?                                                                                                                                                                                  |        5 | What happens when the sun goes down                                                                                                                                                                      |        7
#  25 | What is a verb?                                                                                                                                                                                          | Verb?                                                                                                                                                                                                    |        2 | What is verb                                                                                                                                                                                             |        3
#  26 | Extract the owner of Lamborghini and a listing of the different types of Huracan cars that Lamborghini has produced for its Motorsport division.                                                         | Owner of Lamborghini; list Huracan variants produced for Lamborghini Motorsport.                                                                                                                         |       21 | Extract owner of Lamborghini and listing of different types of Huracan cars Lamborghini has produced for its Motorsport division                                                                         |       27
#  27 | Which of the following is useful for transportation: a glass of wine, a lamp, a train, an iced cube tray, a plane, a bicycle, an apple and a scooter.                                                    | Which items are useful for transportation: glass of wine, lamp, train, ice cube tray, plane, bicycle, apple, scooter?                                                                                    |       29 | Which of these are useful for transportation: glass of wine, lamp, train, iced cube tray, plane, bicycle, apple, scooter                                                                                 |       30
#  28 | Identify which instrument is string or woodwind: Panduri, Zurna                                                                                                                                          | Panduri, Zurna: string or woodwind?                                                                                                                                                                      |       13 | Identify whether Panduri or Zurna string or woodwind                                                                                                                                                     |       14
#  29 | What is the average lifespan of a Golden Retriever?                                                                                                                                                      | Golden Retriever average lifespan?                                                                                                                                                                       |        6 | What is the average lifespan of a Golden Retriever                                                                                                                                                       |       11
#  30 | Who became king of Holland in 1806?                                                                                                                                                                      | 1806 Holland king?                                                                                                                                                                                       |        6 | Who became king of Holland in 1806                                                                                                                                                                       |        9
#  32 | Who played Billy the Kid in The Left Handed Gun                                                                                                                                                          | The Left Handed Gun Billy the Kid actor?                                                                                                                                                                 |       11 | Who played Billy the Kid in The Left Handed Gun                                                                                                                                                          |       12
#  34 | what is REST API                                                                                                                                                                                         | REST API?                                                                                                                                                                                                |        4 | What is REST API                                                                                                                                                                                         |        5
#  41 | Using examples taken from the text give me a summary of the main arguments in favour of slavery reparations in the United States and the anticipated cost of enacting such reparations                   | From the text, summarize main arguments for U.S. slavery reparations and the estimated cost, using examples.                                                                                             |       23 | Using examples from the text summarize main arguments in favor of slavery reparations in the United States and anticipated cost of enacting such reparations                                             |       30
#  42 | When was the wheel invented?                                                                                                                                                                             | Wheel invention date?                                                                                                                                                                                    |        4 | When was the wheel invented                                                                                                                                                                              |        5
#  46 | What is Sunshine Recession?                                                                                                                                                                              | Sunshine Recession?                                                                                                                                                                                      |        4 | What is Sunshine Recession                                                                                                                                                                               |        5
#  47 | What is the currency in use in the Netherlands?                                                                                                                                                          | Currency used in the Netherlands?                                                                                                                                                                        |        6 | What currency is used in the Netherlands                                                                                                                                                                 |        7
#  48 | What is the best tv series in the world                                                                                                                                                                  | Best TV series worldwide?                                                                                                                                                                                |        5 | What is the best TV series in the world                                                                                                                                                                  |        9
#  49 | Who was the first to record the Needles and Pins song?                                                                                                                                                   | Who first recorded Needles and Pins?                                                                                                                                                                     |        8 | Who was first to record Needles and Pins song                                                                                                                                                            |       10
#  50 | Provide me a list of the different types of harnesses used in rock climbing                                                                                                                              | List rock climbing harness types.                                                                                                                                                                        |        6 | List harness types used in rock climbing                                                                                                                                                                 |        7
#  53 | What is enriched air and why would divers dive with enriched air?                                                                                                                                        | What is enriched air and why do divers use it?                                                                                                                                                           |       12 | What is enriched air and why divers dive with enriched air                                                                                                                                               |       13
#  54 | What film won the 1943 Oscar as best film                                                                                                                                                                | 1943 Best Picture winner?                                                                                                                                                                                |        5 | What film won the 1943 Oscar for Best Picture                                                                                                                                                            |        9
#  56 | Given this paragraph, what is the top speed of a Kia Stinger?                                                                                                                                            | Kia Stinger top speed from this paragraph?                                                                                                                                                               |       10 | Given paragraph, top speed of Kia Stinger; Return only JSON with key compressed_prompt                                                                                                                   |       22
#  58 | What is your favorite strip from the comic Calvin and Hobbes?                                                                                                                                            | Your favorite Calvin and Hobbes strip?                                                                                                                                                                   |        9 | What is your favorite Calvin and Hobbes strip                                                                                                                                                            |       10
#  63 | Identify which instrument is string or percussion: Kpanlogo, Shamisen                                                                                                                                    | String or percussion: Kpanlogo, Shamisen                                                                                                                                                                 |       13 | Which instrument is string or percussion: Kpanlogo, Shamisen                                                                                                                                             |       16
#  65 | Classify each of the following as a primary color or a secondary color                                                                                                                                   | Classify each color as primary or secondary.                                                                                                                                                             |        9 | Classify each of the following as primary or secondary color                                                                                                                                             |       11
#  68 | What is the future for human?                                                                                                                                                                            | Future of humanity?                                                                                                                                                                                      |        4 | What is the future for human                                                                                                                                                                             |        6
#  69 | Name some of the bravolebrities from Vanderpump Rules                                                                                                                                                    | Name Bravolebrities from Vanderpump Rules.                                                                                                                                                               |       12 | Name some bravolebrities from Vanderpump Rules                                                                                                                                                           |       13
# ...
# 104 | Categorize each of the following instruments as either string or keyboard: Guitar, Violin, piano, harmonium, cello, accordion, banjo                                                                     | Categorize as string or keyboard: Guitar, Violin, piano, harmonium, cello, accordion, banjo                                                                                                              |       29 | Categorize each of the following instruments as either string or keyboard: Guitar, Violin, piano, harmonium, cello, accordion, banjo                                                                     |       35
# 107 | Change the following passage to past tense                                                                                                                                                               | Change passage to past tense.                                                                                                                                                                            |        8 | Change following passage to past tense; return only JSON with key compressed_prompt                                                                                                                      |       20
# 108 | What is the tallest mountain in the continental US?                                                                                                                                                      | Tallest mountain in continental US?                                                                                                                                                                      |        7 | What is the tallest mountain in the continental US                                                                                                                                                       |       10
# 109 | Who is Shoji Hashimoto?                                                                                                                                                                                  | Shoji Hashimoto?                                                                                                                                                                                         |        6 | Who is Shoji Hashimoto                                                                                                                                                                                   |        7
# 110 | What are some of the best comedy movies of the 1980's?                                                                                                                                                   | Best 1980s comedy movies?                                                                                                                                                                                |        6 | What are best 1980s comedy movies                                                                                                                                                                        |        7
# 112 | What are common ingredients of a full english breakfast?                                                                                                                                                 | Common ingredients of a Full English breakfast?                                                                                                                                                          |        9 | What are common ingredients of a Full English breakfast                                                                                                                                                  |       10
# 114 | How do you operate a car with a manual transmission?                                                                                                                                                     | How to drive a manual transmission car?                                                                                                                                                                  |        9 | How to operate a car with a manual transmission                                                                                                                                                          |       11
# 117 | What is the name of the Winslow's nerdy next-door neighbor on the TV show "Family Matters"?                                                                                                              | Name the Winslow family's nerdy next-door neighbor in Family Matters.                                                                                                                                    |       21 | What is the name of Winslow's nerdy next-door neighbor on TV show Family Matters                                                                                                                         |       24
# 118 | Why are so many US Hollywood films made in the state of Georgia?                                                                                                                                         | Why are so many US Hollywood films made in Georgia?                                                                                                                                                      |       11 | Why are many U.S. Hollywood films made in Georgia                                                                                                                                                        |       12
# 119 | How many managers have Arsenal had?                                                                                                                                                                      | How many Arsenal managers?                                                                                                                                                                               |        5 | How many managers has Arsenal had                                                                                                                                                                        |        6
# Total rows where A's compression is shorter: 58 out of 120
#
# Rows where B's compressed prompt is shorter than A's by at least 2 tokens:
# Idx | A Orig                                   | A Compr                                  | A CompTok | B Compr                                  | B CompTok
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#  13 | From the passage list down the areas for which Dar es Salaam is Tanzania's most prominent city. List the results in comma separated format.                                                              | From the passage, list areas where Dar es Salaam is Tanzania's most prominent city, comma-separated.                                                                                                     |       31 | From the passage list areas where Dar es Salaam is Tanzania's most prominent city list results comma separated                                                                                           |       26
#  22 | What individual has won the most Olympic gold medals in the history of the games?                                                                                                                        | Who has the most Olympic gold medals in Olympic history?                                                                                                                                                 |       12 | Who has won the most Olympic gold medals                                                                                                                                                                 |        9
#  23 | Which Dutch artist painted “Girl with a Pearl Earring”?                                                                                                                                                  | Which Dutch artist painted “Girl with a Pearl Earring”?                                                                                                                                                  |       18 | Which Dutch artist painted Girl with a Pearl Earring                                                                                                                                                     |       12
#  36 | Give me a list of some characteristics of a good coffee shop?                                                                                                                                            | List some characteristics of a good coffee shop?                                                                                                                                                         |       10 | List characteristics of a good coffee shop                                                                                                                                                               |        8
#  37 | Please summarize what Linkedin does.                                                                                                                                                                     | Please summarize what Linkedin does.                                                                                                                                                                     |        8 | Summarize what LinkedIn does                                                                                                                                                                             |        6
#  43 | write a scene between two actors discussing movie Inception                                                                                                                                              | Write scene between two actors discussing Inception.                                                                                                                                                     |        9 | Scene between two actors discussing Inception                                                                                                                                                            |        7
#  59 | What makes a formula one car so fast?                                                                                                                                                                    | What makes F1 cars so fast?                                                                                                                                                                              |        8 | What makes Formula One car fast                                                                                                                                                                          |        6
#  60 | Without quoting directly from the text give me a summary of the history of the Key Lime Pie.                                                                                                             | Summarize the history of Key Lime Pie without direct quotes.                                                                                                                                             |       14 | Summarize history of Key Lime Pie without direct quotes                                                                                                                                                  |       12
#  66 | Where are the British Virgin Islands (BVI) and which islands are a part of the BVI?                                                                                                                      | Where are the British Virgin Islands (BVI) located and which islands comprise the BVI?                                                                                                                   |       19 | Where are British Virgin Islands (BVI) and which islands are part of BVI                                                                                                                                 |       17
#  79 | Which of these are rappers? Eminem, Michael Jackson, Rihanna, 50 Cent                                                                                                                                    | Which of these are rappers? Eminem, Michael Jackson, Rihanna, 50 Cent                                                                                                                                    |       20 | Which of these are rappers Eminem Michael Jackson Rihanna 50 Cent                                                                                                                                        |       16
#  84 | Classify each of the following pieces of equipment according to the sport they are used for, either basketball, football, or soccer: shin guards, shooting sleeve, penalty flag, corner flag, kicking te | Identify sport (basketball, football, soccer) for each item: shin guards, shooting sleeve, penalty flag, corner flag, kicking tee, goalie gloves.                                                        |       47 | Classify equipment by sport used: basketball, football, or soccer; shin guards, shooting sleeve, penalty flag, corner flag, kicking tee, goalie gloves                                                   |       44
#  97 | Write a short story about a person who discovers a hidden room in their house. The story should include a plot twist and a clear resolution at the end.                                                  | Write a short story: a person discovers a hidden room in their house; include a plot twist and a clear resolution at the end.                                                                            |       33 | Write short story about a person discovering hidden room in house; include plot twist; provide clear resolution at end                                                                                   |       22
# 113 | Plan for a three day road trip for May long weekend from Westfield, New Jersey                                                                                                                           | Plan for a three day road trip for May long weekend from Westfield, New Jersey                                                                                                                           |       18 | Plan three day road trip for May long weekend from Westfield, New Jersey                                                                                                                                 |       15
# 115 | What is the Research Collaboratory for Structural Bioinformatics Protein Data Bank (RCSB PDB)?                                                                                                           | What is RCSB PDB (Research Collaboratory for Structural Bioinformatics Protein Data Bank)?                                                                                                               |       28 | What is Research Collaboratory for Structural Bioinformatics Protein Data Bank (RCSB PDB)                                                                                                                |       26
# Total rows where B's compression is shorter by 2+: 14 out of 120
